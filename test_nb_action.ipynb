# %%
import time
time.sleep(300)
# Out:
# Kernel Id: 2cd1c1c3-538b-4b1f-8b85-1144c6a2ca03
# Starting Spark application
# <table>
# ...

# %%
import time
sc.parallelize(range(2000)).map(lambda x: time.sleep(1)).collect()
# Out:
# Kernel Id: 2cd1c1c3-538b-4b1f-8b85-1144c6a2ca03
# Starting Spark application
# <table>
# ...
